# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 628

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nar'yan-mar
# Processing Record 2 of Set 1 | akureyri
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | happy valley-goose bay
# Processing Record 5 of Set 1 | atafu village
# Processing Record 6 of Set 1 | crane
# Processing Record 7 of Set 1 | telimele
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | tolanaro
# Processing Record 10 of Set 1 | yeppoon
# Processing Record 11 of Set 1 | coahuayana de hidalgo
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | port mathurin
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | oranjemund
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | worland
# Processing Record 19 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 1 | adamstown
# Processing Record 21 of Set 1 | smara
# Processing Record 22 of Set 1 | acarau
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | iskateley
# Processing Record 25 of Set 1 | enewetak
# Processing Record 26 of Set 1 | phalaborwa
# Processing Record 27 of Set 1 | ust-nera
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | labytnangi
# Processing Record 30 of Set 1 | xocali
# Processing Record 31 of Set 1 | waitangi
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | alpine
# Processing Record 34 of Set 1 | sao geraldo do araguaia
# Processing Record 35 of Set 1 | bilibino
# Processing Record 36 of Set 1 | kerikeri
# Processing Record 37 of Set 1 | mount gambier
# Processing Record 38 of Set 1 | west island
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | shangri-la
# City not found. Skipping...
# Processing Record 41 of Set 1 | margate
# Processing Record 42 of Set 1 | ust'-ilimsk
# Processing Record 43 of Set 1 | antsiranana
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | ugoofaaru
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | new yekepa
# Processing Record 48 of Set 1 | anadyr
# Processing Record 49 of Set 1 | puerto natales
# Processing Record 50 of Set 1 | touros
# Processing Record 0 of Set 2 | mong cai
# City not found. Skipping...
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | pelileo
# Processing Record 3 of Set 2 | remire-montjoly
# Processing Record 4 of Set 2 | kozyatyn
# Processing Record 5 of Set 2 | la sarre
# Processing Record 6 of Set 2 | chibougamau
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | darfo boario terme
# Processing Record 9 of Set 2 | whitehorse
# Processing Record 10 of Set 2 | tralee
# Processing Record 11 of Set 2 | ejido benito juarez
# City not found. Skipping...
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | sretensk
# Processing Record 1 of Set 5 | bokoro
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | praia da vitoria
# Processing Record 4 of Set 5 | san antonio de pale
# Processing Record 5 of Set 5 | laguna
# Processing Record 6 of Set 5 | auki
# Processing Record 7 of Set 5 | niquelandia
# Processing Record 8 of Set 5 | paphos
# Processing Record 9 of Set 5 | sao francisco
# Processing Record 10 of Set 5 | ceelbuur
# Processing Record 11 of Set 5 | giarmata
# Processing Record 12 of Set 5 | chikwawa
# Processing Record 13 of Set 5 | klyuchi
# Processing Record 14 of Set 5 | saint-gaudens
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | tsiombe
# Processing Record 17 of Set 5 | mamers
# Processing Record 18 of Set 5 | college
# Processing Record 19 of Set 5 | zonguldak
# Processing Record 20 of Set 5 | matoury
# Processing Record 21 of Set 5 | acheng
# Processing Record 22 of Set 5 | sao luis de montes belos
# Processing Record 23 of Set 5 | kavaratti
# Processing Record 24 of Set 5 | kalifornsky
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | san jose village
# City not found. Skipping...
# Processing Record 27 of Set 5 | kapuskasing
# Processing Record 28 of Set 5 | saudarkrokur
# Processing Record 29 of Set 5 | asau
# Processing Record 30 of Set 5 | burang
# Processing Record 31 of Set 5 | xining
# Processing Record 32 of Set 5 | umba
# Processing Record 33 of Set 5 | fortaleza
# Processing Record 34 of Set 5 | gutao
# Processing Record 35 of Set 5 | nagato
# Processing Record 36 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 5 | hanawa
# Processing Record 38 of Set 5 | palmer
# Processing Record 39 of Set 5 | curuca
# Processing Record 40 of Set 5 | mbandjok
# Processing Record 41 of Set 5 | araripina
# Processing Record 42 of Set 5 | khandyga
# Processing Record 43 of Set 5 | chai buri
# Processing Record 44 of Set 5 | itamaraca
# Processing Record 45 of Set 5 | bismarck
# Processing Record 46 of Set 5 | velikiye luki
# Processing Record 47 of Set 5 | calama
# Processing Record 48 of Set 5 | norfolk
# Processing Record 49 of Set 5 | barra de santo antonio
# Processing Record 0 of Set 6 | al hudaydah
# Processing Record 1 of Set 6 | margaret river
# Processing Record 2 of Set 6 | jumla
# Processing Record 3 of Set 6 | nagqu
# Processing Record 4 of Set 6 | santiago de cao
# Processing Record 5 of Set 6 | port moresby
# Processing Record 6 of Set 6 | hepo
# Processing Record 7 of Set 6 | el granada
# Processing Record 8 of Set 6 | taroa
# Processing Record 9 of Set 6 | sanctuary point
# Processing Record 10 of Set 6 | sinop
# Processing Record 11 of Set 6 | kununurra
# Processing Record 12 of Set 6 | pont rouge
# Processing Record 13 of Set 6 | peterhead
# Processing Record 14 of Set 6 | tierralta
# Processing Record 15 of Set 6 | fort bragg
# Processing Record 16 of Set 6 | kapoeta
# Processing Record 17 of Set 6 | tambopata
# Processing Record 18 of Set 6 | leribe
# Processing Record 19 of Set 6 | portland
# Processing Record 20 of Set 6 | port blair
# Processing Record 21 of Set 6 | kidal
# Processing Record 22 of Set 6 | fisterra
# Processing Record 23 of Set 6 | cestos city
# Processing Record 24 of Set 6 | general conesa
# Processing Record 25 of Set 6 | murrells inlet
# Processing Record 26 of Set 6 | acoyapa
# Processing Record 27 of Set 6 | chimore
# Processing Record 28 of Set 6 | manismata
# Processing Record 29 of Set 6 | camiri
# Processing Record 30 of Set 6 | lazaro cardenas
# Processing Record 31 of Set 6 | patong
# Processing Record 32 of Set 6 | al fuwayliq
# Processing Record 33 of Set 6 | olgii
# City not found. Skipping...
# Processing Record 34 of Set 6 | luganville
# Processing Record 35 of Set 6 | muborak
# Processing Record 36 of Set 6 | nova vicosa
# Processing Record 37 of Set 6 | faya-largeau
# Processing Record 38 of Set 6 | sao joao da barra
# Processing Record 39 of Set 6 | galesong
# Processing Record 40 of Set 6 | flying fish cove
# Processing Record 41 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 42 of Set 6 | amagunze
# Processing Record 43 of Set 6 | niteroi
# Processing Record 44 of Set 6 | mount pearl
# Processing Record 45 of Set 6 | chiungutwa
# Processing Record 46 of Set 6 | graaff-reinet
# Processing Record 47 of Set 6 | alesund
# Processing Record 48 of Set 6 | chiang mai
# Processing Record 49 of Set 6 | kampene
# Processing Record 0 of Set 7 | vernon
# Processing Record 1 of Set 7 | constantia
# Processing Record 2 of Set 7 | obihiro
# Processing Record 3 of Set 7 | siwa oasis
# Processing Record 4 of Set 7 | oriximina
# Processing Record 5 of Set 7 | tarfaya
# Processing Record 6 of Set 7 | leer
# Processing Record 7 of Set 7 | okhotsk
# Processing Record 8 of Set 7 | weno
# Processing Record 9 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 7 | brisas de zicatela
# Processing Record 11 of Set 7 | reggane
# Processing Record 12 of Set 7 | qianzhou
# Processing Record 13 of Set 7 | shchekino
# Processing Record 14 of Set 7 | longyearbyen
# Processing Record 15 of Set 7 | trondheim
# Processing Record 16 of Set 7 | gaspe
# Processing Record 17 of Set 7 | aasiaat
# Processing Record 18 of Set 7 | hithadhoo
# Processing Record 19 of Set 7 | kingston
# Processing Record 20 of Set 7 | tura
# Processing Record 21 of Set 7 | selfoss
# Processing Record 22 of Set 7 | rosarito
# Processing Record 23 of Set 7 | markovo
# Processing Record 24 of Set 7 | nueva gerona
# Processing Record 25 of Set 7 | nikolayevsk-on-amure
# Processing Record 26 of Set 7 | puerto maldonado
# Processing Record 27 of Set 7 | puerto baquerizo moreno
# Processing Record 28 of Set 7 | rawlins
# Processing Record 29 of Set 7 | kone
# Processing Record 30 of Set 7 | arthur's town
# City not found. Skipping...
# Processing Record 31 of Set 7 | klaksvik
# Processing Record 32 of Set 7 | toma
# Processing Record 33 of Set 7 | hawaiian paradise park
# Processing Record 34 of Set 7 | kangasniemi
# Processing Record 35 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 7 | morondava
# Processing Record 37 of Set 7 | angaur state
# Processing Record 6 of Set 9 | shingu
# Processing Record 7 of Set 9 | ilhabela
# Processing Record 8 of Set 9 | monte caseros
# Processing Record 9 of Set 9 | carutapera
# Processing Record 10 of Set 9 | cabedelo
# Processing Record 11 of Set 9 | ponta delgada
# Processing Record 12 of Set 9 | nemuro
# Processing Record 13 of Set 9 | quepos
# Processing Record 14 of Set 9 | saldanha
# Processing Record 15 of Set 9 | puerto aysen
# Processing Record 16 of Set 9 | puerto madero
# Processing Record 17 of Set 9 | pajacuaran
# Processing Record 18 of Set 9 | hadibu
# Processing Record 19 of Set 9 | hasaki
# Processing Record 20 of Set 9 | la ronge
# Processing Record 21 of Set 9 | santa vitoria do palmar
# Processing Record 22 of Set 9 | duki
# Processing Record 23 of Set 9 | saint-louis
# Processing Record 24 of Set 9 | vohipaho
# City not found. Skipping...
# Processing Record 25 of Set 9 | prineville
# Processing Record 26 of Set 9 | kabo
# Processing Record 27 of Set 9 | rock springs
# Processing Record 28 of Set 9 | tlacotepec
# Processing Record 29 of Set 9 | king's lynn
# Processing Record 30 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 31 of Set 9 | saipan
# Processing Record 32 of Set 9 | kurumkan
# Processing Record 33 of Set 9 | i-n-salah
# Processing Record 34 of Set 9 | corner brook
# Processing Record 35 of Set 9 | salalah
# Processing Record 36 of Set 9 | minas de marcona
# Processing Record 37 of Set 9 | chivacoa
# Processing Record 38 of Set 9 | beledweyne
# Processing Record 39 of Set 9 | mogadishu
# Processing Record 40 of Set 9 | bamor kalan
# Processing Record 41 of Set 9 | aykol
# City not found. Skipping...
# Processing Record 42 of Set 9 | yatou
# Processing Record 43 of Set 9 | bargara
# City not found. Skipping...
# Processing Record 44 of Set 9 | powell river
# Processing Record 45 of Set 9 | mata-utu
# Processing Record 46 of Set 9 | pak phanang
# Processing Record 47 of Set 9 | aransas pass
# Processing Record 48 of Set 9 | westport
# Processing Record 49 of Set 9 | antonio enes
# Processing Record 0 of Set 10 | baskale
# Processing Record 1 of Set 10 | jayapura
# Processing Record 2 of Set 10 | arno
# Processing Record 3 of Set 10 | satipo
# Processing Record 4 of Set 10 | timimoun
# Processing Record 5 of Set 10 | mahabe
# City not found. Skipping...
# Processing Record 6 of Set 10 | timmins
# Processing Record 7 of Set 10 | utrik
# Processing Record 8 of Set 10 | ghat
# Processing Record 9 of Set 10 | zaozersk
# Processing Record 10 of Set 10 | daru
# Processing Record 11 of Set 10 | williams lake
# Processing Record 12 of Set 10 | harstad
# Processing Record 13 of Set 10 | mecca
# Processing Record 14 of Set 10 | saint-philippe
# Processing Record 15 of Set 10 | dzhambeyty
# Processing Record 16 of Set 10 | stephenville
# Processing Record 17 of Set 10 | saidpur
# Processing Record 18 of Set 10 | mgandu
# Processing Record 19 of Set 10 | tahoua
# Processing Record 20 of Set 10 | birjand
# Processing Record 21 of Set 10 | emmett
# Processing Record 22 of Set 10 | carloforte
# Processing Record 23 of Set 10 | bathsheba
# Processing Record 24 of Set 10 | esquina
# Processing Record 25 of Set 10 | sitka
# Processing Record 26 of Set 10 | arivonimamo
# Processing Record 27 of Set 10 | suva
# Processing Record 28 of Set 10 | prince rupert
# Processing Record 29 of Set 10 | eydhafushi
# Processing Record 30 of Set 10 | morehead city
# Processing Record 31 of Set 10 | mogocha
# Processing Record 32 of Set 10 | strathmore
# Processing Record 33 of Set 10 | lata
# Processing Record 34 of Set 10 | konarka
# Processing Record 35 of Set 10 | karaton
# Processing Record 36 of Set 10 | cambria
# Processing Record 37 of Set 10 | buka
# Processing Record 38 of Set 10 | fale old settlement
# Processing Record 39 of Set 10 | thinadhoo
# Processing Record 40 of Set 10 | chonchi
# Processing Record 41 of Set 10 | tari
# Processing Record 42 of Set 10 | huilong
# Processing Record 43 of Set 10 | sambava
# Processing Record 44 of Set 10 | nanao
# Processing Record 45 of Set 10 | saarlouis
# Processing Record 46 of Set 10 | san luis
# Processing Record 47 of Set 10 | east london
# Processing Record 48 of Set 10 | sur
# Processing Record 49 of Set 10 | villa gesell
# Processing Record 0 of Set 11 | pandan
# Processing Record 1 of Set 11 | tommot
# Processing Record 2 of Set 11 | talcahuano
# Processing Record 3 of Set 11 | seaside
# Processing Record 4 of Set 11 | aswan
# Processing Record 5 of Set 11 | griffith
# Processing Record 6 of Set 11 | agadez
# Processing Record 7 of Set 11 | ancud
# Processing Record 8 of Set 11 | letterkenny
# Processing Record 9 of Set 11 | plettenberg bay
# Processing Record 10 of Set 11 | enriquillo
# Processing Record 11 of Set 11 | whyalla stuart
# City not found. Skipping...
# Processing Record 12 of Set 11 | lompoc
# Processing Record 13 of Set 11 | mount pleasant
# Processing Record 14 of Set 11 | santa cruz
# Processing Record 15 of Set 11 | genhe
# Processing Record 16 of Set 11 | la toma
# Processing Record 17 of Set 11 | black river
# Processing Record 18 of Set 11 | egilsstadir
# Processing Record 19 of Set 11 | tannum sands
# Processing Record 20 of Set 11 | smithers
# Processing Record 21 of Set 11 | yaren
# Processing Record 22 of Set 11 | maine soroa
# Processing Record 23 of Set 11 | lospalos
# Processing Record 24 of Set 11 | kerbakhiar
# Processing Record 25 of Set 11 | lubuklinggau
# Processing Record 26 of Set 11 | tazacorte
# Processing Record 27 of Set 11 | urucui
# Processing Record 28 of Set 11 | port douglas
# Processing Record 29 of Set 11 | guarda
# Processing Record 30 of Set 11 | al bayda
# Processing Record 31 of Set 11 | jijiga
# Processing Record 32 of Set 11 | duong dong
# Processing Record 33 of Set 11 | luanda
# Processing Record 34 of Set 11 | porto novo
# Processing Record 35 of Set 11 | lashio
# Processing Record 36 of Set 11 | lubang
# Processing Record 37 of Set 11 | midland
# Processing Record 38 of Set 11 | pacific grove
# Processing Record 39 of Set 11 | new norfolk
# Processing Record 40 of Set 11 | loacan
# Processing Record 41 of Set 11 | gadzhiyevo
# Processing Record 42 of Set 11 | faratsiho
# Processing Record 43 of Set 11 | usinsk
# Processing Record 44 of Set 11 | villa ojo de agua
# Processing Record 45 of Set 11 | beira
# Processing Record 46 of Set 11 | keflavik
# Processing Record 47 of Set 11 | chernihiv
# Processing Record 48 of Set 11 | patterson
# Processing Record 49 of Set 11 | queenstown
# Processing Record 0 of Set 12 | zambezi
# Processing Record 1 of Set 12 | tazovsky
# Processing Record 2 of Set 12 | don carlos
# Processing Record 3 of Set 12 | santana
# Processing Record 4 of Set 12 | mendi
# Processing Record 5 of Set 12 | kaohsiung
# Processing Record 6 of Set 12 | seydi
# Processing Record 7 of Set 12 | ijuw
# City not found. Skipping...
# Processing Record 8 of Set 12 | ribas do rio pardo
# Processing Record 9 of Set 12 | belabo
# Processing Record 10 of Set 12 | gorom-gorom
# Processing Record 11 of Set 12 | hoxtolgay
# City not found. Skipping...
# Processing Record 12 of Set 12 | rio branco
# Processing Record 13 of Set 12 | mar del plata
# Processing Record 14 of Set 12 | crespo
# Processing Record 15 of Set 12 | sharlyk
# Processing Record 16 of Set 12 | ceres
# Processing Record 17 of Set 12 | issoudun
# Processing Record 18 of Set 12 | porto velho
# Processing Record 19 of Set 12 | atbara
# Processing Record 20 of Set 12 | 'ain el melh
# Processing Record 21 of Set 12 | palikir - national government center
# Processing Record 22 of Set 12 | ta`u
# Processing Record 23 of Set 12 | fonte boa
# Processing Record 24 of Set 12 | manta
# Processing Record 25 of Set 12 | ola
# Processing Record 26 of Set 12 | tarawa
# Processing Record 27 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 12 | dauphin
# Processing Record 29 of Set 12 | virrat
# Processing Record 30 of Set 12 | vorkuta
# Processing Record 31 of Set 12 | khovd
# Processing Record 32 of Set 12 | kirakira
# Processing Record 33 of Set 12 | lautoka
# Processing Record 34 of Set 12 | general acha
# Processing Record 35 of Set 12 | pervomayskoye
# Processing Record 36 of Set 12 | puerto santa
# Processing Record 37 of Set 12 | daloa
# Processing Record 38 of Set 12 | jwaneng
# Processing Record 39 of Set 12 | macas
# Processing Record 40 of Set 12 | bam
# Processing Record 41 of Set 12 | newman
# Processing Record 42 of Set 12 | leava
# Processing Record 43 of Set 12 | rosso
# Processing Record 44 of Set 12 | bikenibeu village
# Processing Record 45 of Set 12 | bertoua
# Processing Record 46 of Set 12 | kiunga
# Processing Record 47 of Set 12 | mahabad
# Processing Record 48 of Set 12 | conception bay south
# Processing Record 49 of Set 12 | dubbo
# Processing Record 0 of Set 13 | mount isa
# Processing Record 1 of Set 13 | coxim
# Processing Record 2 of Set 13 | pontes e lacerda
# Processing Record 3 of Set 13 | mangrol
# Processing Record 4 of Set 13 | maintirano
# Processing Record 5 of Set 13 | xilin hot
# Processing Record 6 of Set 13 | dolisie
# Processing Record 7 of Set 13 | pangody
# Processing Record 8 of Set 13 | el tocuyo
# Processing Record 9 of Set 13 | ilha de mocambique
# Processing Record 10 of Set 13 | garachico
# Processing Record 11 of Set 13 | taraz
# Processing Record 12 of Set 13 | bomdila
# Processing Record 13 of Set 13 | wittstock
# Processing Record 14 of Set 13 | caleta de carquin
# Processing Record 15 of Set 13 | tengrela
# Processing Record 16 of Set 13 | cargados carajos
# City not found. Skipping...
# Processing Record 17 of Set 13 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 18 of Set 13 | mbanza-ngungu
# Processing Record 19 of Set 13 | hilo
# Processing Record 20 of Set 13 | diapaga
# Processing Record 21 of Set 13 | kochubey
# Processing Record 22 of Set 13 | port lincoln
# Processing Record 23 of Set 13 | kristiansund
# Processing Record 24 of Set 13 | casablanca
# Processing Record 25 of Set 13 | sakaiminato
# Processing Record 26 of Set 13 | olot shahri
# City not found. Skipping...
# Processing Record 27 of Set 13 | mirny
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          592
# Lat           592
# Lng           592
# Max Temp      592
# Humidity      592
# Cloudiness    592
# Wind Speed    592
# Country       592
# Date          592
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             nar'yan-mar  67.6713   53.0870     -0.50        95         100
# 1                akureyri  65.6835  -18.0878     -0.04       100         100
# 2                 iqaluit  63.7506  -68.5145     -3.15        63         100
# 3  happy valley-goose bay  53.3168  -60.3315     -3.83        54          20
# 4           atafu village  -8.5421 -172.5159     29.01        71         100
#
#    Wind Speed Country        Date
# 0        9.39      RU  1699244915
# 1        4.63      IS  1699244915
# 2       12.86      CA  1699244915
# 3        5.66      CA  1699244916
# 4        1.31      TK  1699244917

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   nar'yan-mar  67.6713   53.0870     -0.50        95
# 1                      akureyri  65.6835  -18.0878     -0.04       100
# 2                       iqaluit  63.7506  -68.5145     -3.15        63
# 3        happy valley-goose bay  53.3168  -60.3315     -3.83        54
# 4                 atafu village  -8.5421 -172.5159     29.01        71
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        9.39      RU  1699244915
# 1               100        4.63      IS  1699244915
# 2               100       12.86      CA  1699244915
# 3                20        5.66      CA  1699244916
# 4               100        1.31      TK  1699244917

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Maxium temperature (degC)')
plt.title('City Latitude vs. Temperature')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'])
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs. Cloudiness')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'])

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs. Wind Speed')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x, y, y_label, text_coord):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_value = x * slope + intercept
    line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'
    
    plt.scatter(x, y)
    plt.plot(x, regress_value, 'r-')
    plt.annotate(line_eq, text_coord, fontsize=15, color='red')
    plt.xlabel('Lat')
    plt.ylabel(y_label)
    print(f'The r2-value is {round(rvalue**2,3)}')
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   nar'yan-mar  67.6713   53.0870     -0.50        95
# 1                      akureyri  65.6835  -18.0878     -0.04       100
# 2                       iqaluit  63.7506  -68.5145     -3.15        63
# 3        happy valley-goose bay  53.3168  -60.3315     -3.83        54
# 5                         crane  31.3974 -102.3501     18.32        66
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        9.39      RU  1699244915
# 1               100        4.63      IS  1699244915
# 2               100       12.86      CA  1699244915
# 3                20        5.66      CA  1699244916
# 5                95        6.79      US  1699244917

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4        atafu village  -8.5421 -172.5159     29.01        71         100
# 8             tolanaro -25.0319   46.9987     23.04        83          40
# 9              yeppoon -23.1333  150.7333     27.88        66          21
# 12       port mathurin -19.6833   63.4167     24.72        77          37
# 13           grytviken -54.2811  -36.5092      1.04        99         100
#
#          Wind Speed Country        Date
# City_ID
# 4              1.31      TK  1699244917
# 8             10.80      MG  1699244918
# 9              6.73      AU  1699244919
# 12             4.07      MU  1699244920
# 13             0.37      GS  1699244921

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Max T', (0,-5))
# Out:
# The r2-value is 0.753

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Max T', (-50,30))
# Out:
# The r2-value is 0.47

# %% [markdown]
# **Discussion about the linear relationship:** Strong correlation (r2=0.753) is confirmed between the latitude and the maximum temperature in the northern hemisphere. Lesser correlation, but still moderate in its sifnificance (r2=0.47) is found in the southern hemisphere. In general, when we approach the equator, the temperature increases (and vice versa).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Humidity', (45,20))
# Out:
# The r2-value is 0.051

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Humidity', (-50,20))
# Out:
# The r2-value is 0.026

# %% [markdown]
# **Discussion about the linear relationship:** For both hemispheres, the r2-value is very close to zero when relating the latitude to the humidity. No correlation was confirmed.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Cloudiness', (0,-5))
# Out:
# The r2-value is 0.041

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Cloudiness', (-50,20))
# Out:
# The r2-value is 0.037

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness does not correlate with the latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Wind Speed', (0,12))
# Out:
# The r2-value is 0.05

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Wind Speed', (-50,10))
# Out:
# The r2-value is 0.028

# %% [markdown]
# **Discussion about the linear relationship:** Wind speed does not reveal correlation with the latitude.

# %%
vv
